# %% [markdown]
# # 04 - Analyse de graphe
#
# Ce notebook sert à explorer les interactions de graphe entre entités.

# %%
print('Notebook prêt pour lanalyse de graphe')
# Out:
# Notebook prêt pour lanalyse de graphe
